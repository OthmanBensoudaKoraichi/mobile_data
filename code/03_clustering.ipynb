# %% [markdown]
# *In this notebook, we cluster pings for each mobile, and we write a function to visualize results on a map. Then, we visualize clusters for the first mobile.*

# %% [markdown]
# # Import dataset

# %%
import pandas as pd
clean_mega_data = pd.read_csv("../datasets/clean_mega_data.csv")

# %% [markdown]
# # Cluster all points [DB scan]

# %%
"""
Use DBscan algorithm to cluster pings for each mobile. Note that a single ping can be its own cluster if it is isolated enough.
"""

import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from tqdm import tqdm  # Progress bar

# Assuming clean_mega_data is already loaded
results = []

# DBSCAN parameters
eps = 50 / 111000  # 50 meters converted to degrees

# Loop through each unique CAID
for caid in tqdm(clean_mega_data['caid'].unique(), desc="Processing CAIDs"):
    data_filtered = clean_mega_data[clean_mega_data['caid'] == caid].reset_index(drop=True)

    if data_filtered.empty:
        continue

    # Extract coordinates
    coords = data_filtered[['latitude', 'longitude']].values.astype(np.float32)

    # Apply DBSCAN
    dbscan = DBSCAN(eps=eps, min_samples=1).fit(coords)
    data_filtered['cluster'] = dbscan.labels_

    # Calculate centroids
    centroid_dict = data_filtered.groupby('cluster')[['latitude', 'longitude']].mean().to_dict('index')

    # Add centroid addresses to data
    data_filtered['centroid_address'] = data_filtered['cluster'].map(centroid_dict)

    results.append(data_filtered)

# Combine results into one DataFrame
final_data = pd.concat(results).reset_index(drop=True)

# Save to CSV
final_data.to_csv('clustered_data.csv', index=False)

# %%
final_data.head()
# Out:
#                                                 caid  zipcode  \
# 0  3924b2d36e1b036021dd5cc9ccabf33e20ba55e0f3a531...    90301
# 1  3924b2d36e1b036021dd5cc9ccabf33e20ba55e0f3a531...    90301
# 2  3924b2d36e1b036021dd5cc9ccabf33e20ba55e0f3a531...    90301
# 3  3924b2d36e1b036021dd5cc9ccabf33e20ba55e0f3a531...    90301
# 4  3924b2d36e1b036021dd5cc9ccabf33e20ba55e0f3a531...    90301
#
#              utc_timestamp  latitude  longitude  horizontal_accuracy  \
# 0  2024-02-14 05:33:33.000  33.95756 -118.37116                 33.0
# 1  2024-02-14 06:18:44.000  33.95456 -118.35538                  5.0
# 2  2024-02-14 05:12:58.000  33.95747 -118.37079                 12.0
# 3  2024-02-14 05:33:38.000  33.95754 -118.37114                 33.0
# 4  2024-02-14 06:42:13.000  33.95672 -118.35954                  5.0
#
#        region  ping_near_replicate_matches quarter  cluster  \
# 0  california                            1       2        0
# 1  california                            1       2        1
# 2  california                            1       2        0
# 3  california                            1       2        0
# 4  california                            1       2        2
#
#                                     centroid_address
# 0  {'latitude': 33.95752090909091, 'longitude': -...
# 1  {'latitude': 33.954546, 'longitude': -118.3553...
# 2  {'latitude': 33.95752090909091, 'longitude': -...
# 3  {'latitude': 33.95752090909091, 'longitude': -...
# 4  {'latitude': 33.956678, 'longitude': -118.3595...

# %% [markdown]
# # Visualize results (function)

# %%
import pandas as pd
final_data = pd.read_csv('../datasets/clustered_data.csv')

# %%
final_data.shape
# Out:
# (10332575, 11)

# %%
import pandas as pd
import folium
import random  # For color generation

def visualize_caid(data, selected_caid):
    # Filter data for the selected CAID
    data_filtered = data[data['caid'] == selected_caid].reset_index(drop=True)

    if data_filtered.empty:
        print(f"No data found for CAID {selected_caid}")
        return

    # Extract centroid dictionary
    centroid_dict = data_filtered.groupby('cluster')[['latitude', 'longitude']].mean().to_dict('index')

    # Step 7: Visualize with Folium
    map_center = [data_filtered['latitude'].mean(), data_filtered['longitude'].mean()]
    m = folium.Map(location=map_center, zoom_start=12)

    # Generate distinct colors for each cluster
    cluster_colors = {cluster_id: f'#{random.randint(0, 0xFFFFFF):06x}' for cluster_id in centroid_dict.keys()}

    # Add all pings with cluster-specific colors
    for idx, row in data_filtered.iterrows():
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=3,
            color=cluster_colors[row['cluster']],
            fill=True,
            fill_opacity=0.6,
            popup=f"Ping {idx}<br>Cluster {row['cluster']}"
        ).add_to(m)

    # Add cluster centroids as red markers
    for cluster_id, centroid in centroid_dict.items():
        folium.Marker(
            location=[centroid['latitude'], centroid['longitude']],
            icon=folium.Icon(color='red', icon='home'),
            popup=f"Cluster {cluster_id}<br>Centroid: {centroid}"
        ).add_to(m)

    print(f"Selected CAID: {selected_caid}")
    print(f"Filtered Data Size: {data_filtered.shape}")
    print(f"Clusters Found: {len(centroid_dict)}")
    print(f"Centroids: {centroid_dict}")
    print(f"Map Center: {map_center}")

    return m

# %% [markdown]
# # Visualize first caid

# %%
# Visualize for the first CAID
first_caid = final_data['caid'].unique()[220]  # Get the first CAID
visualize_caid(final_data, first_caid)
# Out:
# Selected CAID: eb825d402c58ad560a6cef19a0840aaa8aa8b5a118a431c03cc15dfd05487c96
# Filtered Data Size: (102, 11)
# Clusters Found: 10
# Centroids: {0: {'latitude': 34.169926999999994, 'longitude': -118.26993966666667}, 1: {'latitude': 34.14358958333333, 'longitude': -118.19105541666666}, 2: {'latitude': 34.112777161290325, 'longitude': -118.26858483870967}, 3: {'latitude': 34.14101333333333, 'longitude': -118.14754}, 4: {'latitude': 34.076953333333336, 'longitude': -118.2489}, 5: {'latitude': 34.09064769230769, 'longitude': -118.21174353846155}, 6: {'latitude': 34.09025666666667, 'longitude': -118.2121}, 7: {'latitude': 34.095762, 'longitude': -118.20762914285714}, 8: {'latitude': 34.094967600000004, 'longitude': -118.20805800000001}, 9: {'latitude': 34.14224, 'longitude': -118.14581}}
# Map Center: [np.float64(34.12129282352941), np.float64(-118.22910319607841)]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a4ab6f590aba3ced89be6d18eef7bc1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a4ab6f590aba3ced89be6d18eef7bc1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a4ab6f590aba3ced89be6d18eef7bc1 = L.map(
#                 &quot;map_7a4ab6f590aba3ced89be6d18eef7bc1&quot;,
#                 {
#                     center: [34.12129282352941, -118.22910319607841],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc7009328e635b787814ee772ad5081e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc7009328e635b787814ee772ad5081e.addTo(map_7a4ab6f590aba3ced89be6d18eef7bc1);
#
#
#             var circle_marker_7448dc59c94edb35d6bb56405e08649f = L.circleMarker(
#                 [34.1699, -118.26999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#09557e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#09557e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7a4ab6f590aba3ced89be6d18eef7bc1);
#
#
#         var popup_e1de61ee8c2b1f1cb91f9139b56f5105 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37d810b0c74e6df9a1752558a908a387 = $(`&lt;div id=&quot;html_37d810b0c74e6df9a1752558a908a387&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ping 0&lt;br&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_e1de61ee8c2b1f1cb91f9139b56f5105.setContent(html_37d810b0c74e6df9a1752558a908a387);
#
#
#
#         circle_marker_7448dc59c94edb35d6bb56405e08649f.bindPopup(popup_e1de61ee8c2b1f1cb91f9139b56f5105)
#         ;
#
#
#
#
#             var circle_marker_011568f5bd3e2148f957ff7e150d2166 = L.circleMarker(
#                 [34.16995, -118.26992],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#09557e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#09557e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7a4ab6f590aba3ced89be6d18eef7bc1);
#
#
#         var popup_4f720c0b14bec721f0c088aa3fe4e8ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56b1b1e388477b89caa3abbab84e4adb = $(`&lt;div id=&quot;html_56b1b1e388477b89caa3abbab84e4adb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ping 1&lt;br&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_4f720c0b14bec721f0c088aa3fe4e8ea.setContent(html_56b1b1e388477b89caa3abbab84e4adb);
#
#
#
#         circle_marker_011568f5bd3e2148f957ff7e150d2166.bindPopup(popup_4f720c0b14bec721f0c088aa3fe4e8ea)
#         ;
#
#
#
#
#             var circle_marker_2d9b47820df68b5ffee550b2f4a6be72 = L.circleMarker(
#                 [34.16999, -118.27],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#09557e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#09557e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7a4ab6f590aba3ced89be6d18eef7bc1);
#
#
#         var popup_7e7d4d7ea44de74a8bb5b1bf188758a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69882db4e4124647bdaf83ca3568c281 = $(`&lt;div id=&quot;html_69882db4e4124647bdaf83ca3568c281&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ping 2&lt;br&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_7e7d4d7ea44de74a8bb5b1bf188758a7.setContent(html_69882db4e4124647bdaf83ca3568c281);
#
#
#
#         circle_marker_2d9b47820df68b5ffee550b2f4a6be72.bindPopup(popup_7e7d4d7ea44de74a8bb5b1bf188758a7)
#         ;
#
#
#
#
#             var circle_marker_fabf385a371cfe0c030cb74281687fee = L.circleMarker(
#                 [34.169937, -118.269936],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#09557e&quot;, &quot;dashArray&quot;: nu
